# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize, sent_tokenize
from nltk.stem import PorterStemmer
   
import string
import re
import warnings
warnings.filterwarnings("ignore")

# %%
path = r"C:\Users\DELL\Downloads\spam.csv"

# %%
df = pd.read_csv(path,encoding="latin1")

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.drop(columns=["Unnamed: 2","Unnamed: 3","Unnamed: 4"],inplace=True)

# %%
df.rename(columns={"v1":"Target","v2":"Msg"},inplace=True)

# %%
df.shape
# Out:
# (5572, 2)

# %%
x = df["Msg"][0]
print(x)
# Out:
# Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...

# %%
df.head()
# Out:
#   Target                                                Msg
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.msg = df.msg.str.lower()

# %%
df.head()
# Out:
#   target                                                msg
# 0    ham  go until jurong point, crazy.. available only ...
# 1    ham                      ok lar... joking wif u oni...
# 2   spam  free entry in 2 a wkly comp to win fa cup fina...
# 3    ham  u dun say so early hor... u c already then say...
# 4    ham  nah i don't think he goes to usf, he lives aro...

# %%
x = df.msg[0]

# %%
x
# Out:
# 'go until jurong point, crazy.. available only in bugis n great world la e buffet... cine there got amore wat...'

# %%
lis = []
for i in word_tokenize(x):
    i = i.strip()
    if i not in string.punctuation:
        if i!=".." or i!="...":
            print(i)
# Out:
# go
# until
# jurong
# point
# crazy
# ..
# available
# only
# in
# bugis
# n
# great
# world
# la
# e
# buffet
# ...
# cine
# there
# got
# amore
# wat
# ...

# %%
def syntax(x):
    lis = []
    p = string.punctuation
    w = stopwords.words("english")
    for i in word_tokenize(x):
        if (i not in p) and (i not in w):
            lis.append(i)
    return lis

# %%
syntax("We are learning NLP ?")
# Out:
# ['We', 'learning', 'NLP']

# %%
df["msg2"] = df["msg"].apply(syntax)

# %%
df.head()
# Out:
#   target                                                msg  \
# 0    ham  go until jurong point, crazy.. available only ...
# 1    ham                      ok lar... joking wif u oni...
# 2   spam  free entry in 2 a wkly comp to win fa cup fina...
# 3    ham  u dun say so early hor... u c already then say...
# 4    ham  nah i don't think he goes to usf, he lives aro...
#
#                                                 msg2
# 0  [go, jurong, point, crazy, .., available, bugi...
# 1           [ok, lar, ..., joking, wif, u, oni, ...]
# 2  [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3  [u, dun, say, early, hor, ..., u, c, already, ...
# 4  [nah, n't, think, goes, usf, lives, around, th...

# %%
len(df["msg2"][0])
# Out:
# 19

# %%
def length(x):
    return len(x)

# %%
df["Length"] = df["msg2"].apply(length)

# %%
df.head()
# Out:
#   target                                                msg  \
# 0    ham  go until jurong point, crazy.. available only ...
# 1    ham                      ok lar... joking wif u oni...
# 2   spam  free entry in 2 a wkly comp to win fa cup fina...
# 3    ham  u dun say so early hor... u c already then say...
# 4    ham  nah i don't think he goes to usf, he lives aro...
#
#                                                 msg2  Length
# 0  [go, jurong, point, crazy, .., available, bugi...      19
# 1           [ok, lar, ..., joking, wif, u, oni, ...]       8
# 2  [free, entry, 2, wkly, comp, win, fa, cup, fin...      27
# 3  [u, dun, say, early, hor, ..., u, c, already, ...      11
# 4  [nah, n't, think, goes, usf, lives, around, th...       8

# %%
x = "We are learning NLP"

len(x)
# Out:
# 19

# %%
def char(x):
    c = 0
    for i in x:
        if i.isalpha():
            c+=1
            return c

# %%
c = 0
c +=1
c
# Out:
# 1

# %%
c+=1

# %%
c
# Out:
# 2

# %%
df["characters"] = df["msg"].apply(char)

# %%
df.head()
# Out:
#   target                                                msg  \
# 0    ham  go until jurong point, crazy.. available only ...
# 1    ham                      ok lar... joking wif u oni...
# 2   spam  free entry in 2 a wkly comp to win fa cup fina...
# 3    ham  u dun say so early hor... u c already then say...
# 4    ham  nah i don't think he goes to usf, he lives aro...
#
#                                                 msg2  Length  characters
# 0  [go, jurong, point, crazy, .., available, bugi...      19         1.0
# 1           [ok, lar, ..., joking, wif, u, oni, ...]       8         1.0
# 2  [free, entry, 2, wkly, comp, win, fa, cup, fin...      27         1.0
# 3  [u, dun, say, early, hor, ..., u, c, already, ...      11         1.0
# 4  [nah, n't, think, goes, usf, lives, around, th...       8         1.0
